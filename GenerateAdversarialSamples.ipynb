# %% [markdown]
# # Preprocessing

# %%
import string
import sys
import warnings
from collections import OrderedDict
from collections import defaultdict
import os
import numpy as np
import pandas as pd
import math
import csv
import pickle
import torch
from torch.utils.data import DataLoader, Dataset
import torch.nn as nn
import torch.nn.functional as F
from torch.autograd import Variable
import argparse
import shutil

# %%
if sys.version_info < (3,):
    maketrans = string.maketrans
else:
    maketrans = str.maketrans

def text_to_word_sequence(text,filters='!"#$%&()*+,-./:;<=>?@[\\]^_`{|}~\t\n',lower=True, split=" "):
    
    if lower:
        text = text.lower()

    if sys.version_info < (3,):
        if isinstance(text, unicode):
            translate_map = dict((ord(c), unicode(split)) for c in filters)
            text = text.translate(translate_map)
        elif len(split) == 1:
            translate_map = maketrans(filters, split * len(filters))
            text = text.translate(translate_map)
        else:
            for c in filters:
                text = text.replace(c, split)
    else:
        translate_dict = dict((c, split) for c in filters)
        translate_map = maketrans(translate_dict)
        text = text.translate(translate_map)

    seq = text.split(split)
    return [i for i in seq if i]

# %%
class Tokenizer(object):

    def __init__(self, num_words=None,filters='!"#$%&()*+,-./:;<=>?@[\\]^_`{|}~\t\n',lower=True,split=' ',char_level=False,
                 oov_token=None,document_count=0,**kwargs):
        self.word_counts = OrderedDict()
        self.word_docs = defaultdict(int)
        self.filters = filters
        self.split = split
        self.lower = lower
        self.num_words = num_words
        self.document_count = document_count
        self.char_level = char_level
        self.oov_token = oov_token
        self.index_docs = defaultdict(int)
        self.word_index = dict()
        self.index_word = dict()
    def fit_on_texts(self, texts):
        
        for text in texts:
            self.document_count += 1
            if self.char_level or isinstance(text, list):
                if self.lower:
                    if isinstance(text, list):
                        text = [text_elem.lower() for text_elem in text]
                    else:
                        text = text.lower()
                seq = text
            else:
                seq = text_to_word_sequence(text,
                                            self.filters,
                                            self.lower,
                                            self.split)
            for w in seq:
                if w in self.word_counts:
                    self.word_counts[w] += 1
                else:
                    self.word_counts[w] = 1
            for w in set(seq):
                # In how many documents each word occurs
                self.word_docs[w] += 1

        wcounts = list(self.word_counts.items())
        wcounts.sort(key=lambda x: x[1], reverse=True)
        # forcing the oov_token to index 1 if it exists
        if self.oov_token is None:
            sorted_voc = []
        else:
            sorted_voc = [self.oov_token]
        sorted_voc.extend(wc[0] for wc in wcounts)

        
        self.word_index = dict(list(zip(sorted_voc, list(range(1, len(sorted_voc) + 1)))))

        self.index_word = dict((c, w) for w, c in self.word_index.items())

        for w, c in list(self.word_docs.items()):
            self.index_docs[self.word_index[w]] = c

    def fit_on_sequences(self, sequences):
        self.document_count += len(sequences)
        for seq in sequences:
            seq = set(seq)
            for i in seq:
                self.index_docs[i] += 1

    def texts_to_sequences(self, texts):
        return list(self.texts_to_sequences_generator(texts))

    def texts_to_sequences_generator(self, texts):
        num_words = self.num_words
        oov_token_index = self.word_index.get(self.oov_token)
        for text in texts:
            if self.char_level or isinstance(text, list):
                if self.lower:
                    if isinstance(text, list):
                        text = [text_elem.lower() for text_elem in text]
                    else:
                        text = text.lower()
                seq = text
            else:
                seq = text_to_word_sequence(text,self.filters,self.lower,self.split)
            vect = []
            for w in seq:
                i = self.word_index.get(w)
                if i is not None:
                    if num_words and i >= num_words:
                        if oov_token_index is not None:
                            vect.append(oov_token_index)
                    else:
                        vect.append(i)
                elif self.oov_token is not None:
                    vect.append(oov_token_index)
            yield vect

def pad_sequences(sequences, maxlen=None, dtype='int32',padding='pre', truncating='pre', value=0.):
    if not hasattr(sequences, '__len__'):
        raise ValueError('`sequences` must be iterable.')
    lengths = []
    for x in sequences:
        if not hasattr(x, '__len__'):
            raise ValueError('`sequences` must be a list of iterables. '
                             'Found non-iterable: ' + str(x))
        lengths.append(len(x))

    num_samples = len(sequences)
    if maxlen is None:
        maxlen = np.max(lengths)

    sample_shape = tuple()
    for s in sequences:
        if len(s) > 0:
            sample_shape = np.asarray(s).shape[1:]
            break

    is_dtype_str = np.issubdtype(dtype, np.str_) or np.issubdtype(dtype, np.unicode_)

    x = np.full((num_samples, maxlen) + sample_shape, value, dtype=dtype)
    for idx, s in enumerate(sequences):
        if not len(s):
            continue  
        if truncating == 'pre':
            trunc = s[-maxlen:]
        elif truncating == 'post':
            trunc = s[:maxlen]
        else:
            raise ValueError('Truncating type "%s" '
                             'not understood' % truncating)

        
        trunc = np.asarray(trunc, dtype=dtype)
        if trunc.shape[1:] != sample_shape:
            raise ValueError('Shape of sample %s of sequence at position %s '
                             'is different from expected shape %s' %
                             (trunc.shape[1:], idx, sample_shape))

        if padding == 'post':
            x[idx, :len(trunc)] = trunc
        elif padding == 'pre':
            x[idx, -len(trunc):] = trunc
        else:
            raise ValueError('Padding type "%s" not understood' % padding)
    return x

# %% [markdown]
# # loaddata

# %%
class dataset:
    def __init__(self,filename,line=3):
        self.output = []
        self.content = []
        self.columns=line
        self.loadcsv(filename)
        
    def loadcsv(self, filename):
        reader = csv.reader(open(filename, "rt", encoding = "utf8"))
        count = 0
        for row in reader:
            if not row:
                continue
            if self.columns==2:
                self.output.append(int(row[0])-1)
                self.content.append((row[1]).lower())     
def loaddata(i = 0):
    datanames = ['IMDB'] 
    lines = [2]
    classes= [2]
    # if not 'blog' in datanames[i]:
    trainadd = 'covid_train_25000.csv'
    valadd='covid_val_7500.csv'
    testadd = 'covid_test_17500.csv'
    
    traindata = dataset(trainadd,lines[i])
    valdata=dataset(valadd,lines[i])
    testdata = dataset(testadd,lines[i])                
    return(traindata,valdata,testdata,classes[i])#valdata,
    # else:
    #     data = dataset()
    #     return (traindata,testdata,classes[i])

def loaddatawithtokenize(i = 0, nb_words = 20000, start_char = 1, oov_char=2, index_from=3, withraw = False, datalen = 500):
    (traindata,valdata,testdata,numclass) = loaddata(i)
    rawtrain = traindata.content[:]
    rawval = valdata.content[:]
    rawtest = testdata.content[:]

    tokenizer = Tokenizer(lower=True)
    tokenizer.fit_on_texts(traindata.content + valdata.content+ testdata.content)

    traindata.content = tokenizer.texts_to_sequences(traindata.content)
    valdata.content  = tokenizer.texts_to_sequences(valdata.content)
    testdata.content = tokenizer.texts_to_sequences(testdata.content)
    
    if start_char==None:
        traindata.content = [[w + index_from for w in x] for x in traindata.content]
        valdata.content = [[w + index_from for w in x] for x in valdata.content]
        testdata.content = [[w + index_from for w in x] for x in testdata.content]
        
    else:
        traindata.content = [[start_char]+[w + index_from for w in x] for x in traindata.content]
        valdata.content = [[start_char]+[w + index_from for w in x] for x in valdata.content]
        testdata.content = [[start_char]+[w + index_from for w in x] for x in testdata.content]
       
    
    traindata.content = [[w if w < nb_words else oov_char for w in x] for x in traindata.content]
    valdata.content = [[w if w < nb_words else oov_char for w in x] for x in valdata.content]
    testdata.content = [[w if w < nb_words else oov_char for w in x] for x in testdata.content]
    
    
    traindata.content = pad_sequences(traindata.content, maxlen=datalen)
    valdata.content = pad_sequences(valdata.content, maxlen=datalen)
    testdata.content = pad_sequences(testdata.content, maxlen=datalen)
    
    if withraw:
        return traindata,valdata,testdata,tokenizer,numclass,rawtrain,rawtest
    else:
        return traindata,valdata,testdata,tokenizer,numclass

# %% [markdown]
# # dataloader

# %%
class Worddata(Dataset):
    def __init__(self, data, tokenizer = True, length=1014, space = False, backward = -1, getidx = False, rawdata = None):
        self.backward = backward
        self.length = length
        (self.inputs,self.labels) = (data.content,data.output)
        self.labels = torch.LongTensor(self.labels)
        self.inputs = torch.from_numpy(self.inputs).long()
        self.getidx = getidx
        if rawdata:
            self.raw = rawdata
    def __len__(self):
        return len(self.inputs)
    def __getitem__(self,idx):
        x = self.inputs[idx]
        y = self.labels[idx]
        if self.getidx==True:
            if self.raw:
                return x,y,idx,self.raw[idx]
            else:
                return x,y,idx
        else:
            return x,y

# %% [markdown]
# # model

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
device
# Out:
# device(type='cuda')

# %%
class WordRNN(nn.Module):
    def __init__(self, classes=2, bidirection = False, layernum=1, length=20000,embedding_size =100, hiddensize = 100):
        super(WordRNN, self).__init__()
        self.embd = nn.Embedding(length, embedding_size)
        # self.lstm = nn.LSTMCell(hiddensize, hiddensize)
        self.lstm = nn.LSTM(embedding_size, hiddensize, layernum, bidirectional = bidirection)
        self.hiddensize = hiddensize
        numdirections = 1 + bidirection
        self.hsize = numdirections * layernum
        self.linear = nn.Linear(hiddensize * numdirections, classes)
        self.log_softmax = nn.LogSoftmax()
    def forward(self, x, returnembd = False):
        embd = self.embd(x)
        if returnembd:
            embd = Variable(embd.data, requires_grad=True).to(device)
            embd.retain_grad()
            # print embd.size()
        h0 = Variable(torch.zeros(self.hsize, embd.size(0), self.hiddensize)).to(device)
        c0 = Variable(torch.zeros(self.hsize, embd.size(0), self.hiddensize)).to(device)
        # for inputs in x:
        x = embd.transpose(0,1)
        x,(hn,cn) = self.lstm(x,(h0,c0))
        x = x[-1]
        # x = x[-1].transpose(0,1)
        # x = x.view(x.size(0),-1)
        x = self.log_softmax(self.linear(x))
        if returnembd:
            return embd,x
        else:
            return x

# %%
def save_checkpoint(state, is_best, filename='checkpoint.dat'):
    torch.save(state, filename + '_checkpoint.dat')
    if is_best:
        shutil.copyfile(filename + '_checkpoint.dat', filename + "_bestmodel.dat")

# %%
data=0
wordlength=200
dictionarysize=20000
batchsize=128
backward=-1
epochs=5
lr=0.005

# %%
torch.manual_seed(7)
torch.cuda.manual_seed_all(7)

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

print("Loading data..")
(train,val,test,tokenizer,numclass) = loaddatawithtokenize(data,nb_words = dictionarysize, datalen = wordlength)
trainword = Worddata(train,backward = backward)
valword = Worddata(val,backward = backward)
testword = Worddata(test,backward = backward)
train_loader = DataLoader(trainword,batch_size=batchsize, shuffle = True)#, num_workers=4
val_loader = DataLoader(valword,batch_size=batchsize, shuffle = True)#, num_workers=4
test_loader = DataLoader(testword,batch_size=batchsize)#, num_workers=4
# Out:
# Loading data..

# %%
model = WordRNN(bidirection=True)
model = model.to(device)
#print(model)
optimizer = torch.optim.AdamW(model.parameters(),weight_decay=0.05)#,weight_decay=0.01

# %%
bestacc = 0
for epoch in range(epochs):
    #print('Start epoch %d' % epoch)
    model.train()
    correct_train = .0
    total_loss_train = 0
    for dataid, data in enumerate(train_loader):
        inputs,target = data
        inputs,target = Variable(inputs),  Variable(target)
        inputs, target = inputs.to(device), target.to(device)
        output = model(inputs)

        loss = F.nll_loss(output, target)
        total_loss_train += loss.item()
        pred_train = output.data.max(1, keepdim=True)[1]
        correct_train += pred_train.eq(target.data.view_as(pred_train)).cpu().sum().item()

        optimizer.zero_grad()
        loss.backward()
        optimizer.step()
    
    correct_val= .0
    total_loss_val = 0
    model.eval()
    for dataid, data in enumerate(val_loader):
        inputs,target = data
        inputs, target = inputs.to(device), target.to(device)
        output = model(inputs)
        loss = F.nll_loss(output, target)
        total_loss_val += loss.item()
        pred = output.data.max(1, keepdim=True)[1]
        correct_val += pred.eq(target.data.view_as(pred)).cpu().sum().item()

    acc_train = correct_train/len(train_loader.dataset)
    avg_loss_train = total_loss_train/len(train_loader.dataset)
    acc_val = correct_val/len(val_loader.dataset)
    avg_loss_val = total_loss_val/len(val_loader.dataset)
    print('Epoch %d :'%(epoch+1))
    print('Train_Loss %.4f Train_Accuracy %.5f' % (avg_loss_train,acc_train))
    print('Validation_Loss %.4f Validation_Accuracy %.5f' % (avg_loss_val,acc_val))
    is_best = acc_val > bestacc
    if is_best:
        bestacc = acc_val
    if dictionarysize!=20000:
        fname = "covid_wordrnn_Natural" +str(dictionarysize) + "_" 
    else:
        fname = "covid
    save_checkpoint({
            'epoch': epoch + 1,
            'state_dict': model.state_dict(),
            'bestacc': bestacc,
            'optimizer' : optimizer.state_dict(),
        }, is_best, filename = fname)
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:26: UserWarning: Implicit dimension choice for log_softmax has been deprecated. Change the call to include dim=X as an argument.
# Epoch 1 :
# Train_Loss 0.0047 Train_Accuracy 0.65230
# Validation_Loss 0.0040 Validation_Accuracy 0.74425
# Epoch 2 :
# Train_Loss 0.0032 Train_Accuracy 0.81171
# Validation_Loss 0.0031 Validation_Accuracy 0.82777
# Epoch 3 :
# Train_Loss 0.0023 Train_Accuracy 0.88169
# Validation_Loss 0.0028 Validation_Accuracy 0.85703
# Epoch 4 :
# Train_Loss 0.0017 Train_Accuracy 0.92124
# Validation_Loss 0.0027 Validation_Accuracy 0.86873
# Epoch 5 :
# Train_Loss 0.0012 Train_Accuracy 0.94498
# Validation_Loss 0.0027 Validation_Accuracy 0.87219

# %% [markdown]
# # Evaluate Testset

# %%
correct = 0
total = 0
model.eval()
with torch.no_grad():
    for data in test_loader:
        inputs, labels = data
        inputs, labels = inputs.to(device), labels.to(device)
        outputs = model(inputs)
        _, predicted = torch.max(outputs.data, 1)
        total += labels.size(0)
        correct += (predicted == labels).sum().item()

print('Accuracy of the network on the 17500 clean test images: %.2f %%' % (100 * correct / total))
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:26: UserWarning: Implicit dimension choice for log_softmax has been deprecated. Change the call to include dim=X as an argument.
# Accuracy of the network on the 17500 clean test images: 87.27 %

# %% [markdown]
# Scoring

# %%
def random(model, inputs, pred, classes):
    losses = torch.rand(inputs.size()[0],inputs.size()[1])
    return losses
    # Output a random list

def replaceone(model, inputs, pred, classes):
    losses = torch.zeros(inputs.size()[0],inputs.size()[1])
    for i in range(inputs.size()[1]):
        tempinputs = inputs.clone()
        tempinputs[:,i]=2
        with torch.no_grad():
            tempoutput = model(tempinputs)
        losses[:,i] = F.nll_loss(tempoutput, pred, reduce=False)
    return losses


def scorefunc(name):
    if "replaceone" in name:
        return replaceone
    elif "random" in name:
        return random
    else:
        print('No scoring function found')

# %% [markdown]
# Transformer

# %%
def insert(wordid,word_index,index2word,top_words=20000):
    word = index2word[wordid]
    s = np.random.randint(0,len(word)+1)
    cword = word[:s] + chr(97+np.random.randint(0,26)) + word[s:]
    if cword in word_index:
        wid = word_index[cword] + 3
        if wid>=top_words:
            wid = 2
    else:
        wid = 2
    return (cword,wid)

def delete(wordid,word_index,index2word,top_words=20000):
    word = index2word[wordid]
    s = np.random.randint(0,len(word))
    if len(word)>1:
        cword = word[:s] + word[s+1:]
    else:
        cword = word
    if cword in word_index:
        wid = word_index[cword] + 3
        if wid>=top_words:
            wid = 2
    else:
        wid = 2
    return (cword,wid)

def swap(wordid,word_index,index2word,top_words=20000):
    word = index2word[wordid]
    if len(word)!=1:
        s = np.random.randint(0,len(word)-1)
        cword = word[:s] + word[s+1] + word[s] + word[s+2:]
        if cword in word_index:
            wid = word_index[cword] + 3
            if wid>=top_words:
                wid = 2
        else:
            wid = 2
    else:
        cword = word
        if cword in word_index:
            wid = word_index[cword] + 3
            if wid>=top_words:
                wid = 2
        else:
            wid = 2
    return (cword,wid)
    
def transform(name):
  if "swap" in name:
    return swap
  elif "insert" in name:
    return insert
  elif "delete" in name:
    return delete
  else:
    print('No transformer function found')

# %% [markdown]
# Attack

# %%
torch.manual_seed(8)
torch.cuda.manual_seed(8)

# %%
modelpath='covid_wordrnn_Natural__bestmodel.dat'
power=10
scoring="replaceone"
transformer="insert"
maxbatches=30
data=0
wordlength=200
dictionarysize=20000
batchsize=128

# %%
(train,val,test,tokenizer,numclass, rawtrain, rawtest) = loaddatawithtokenize(data, nb_words = dictionarysize, datalen = wordlength, withraw=True)
word_index = tokenizer.word_index
trainword = Worddata(train, getidx = True, rawdata = rawtrain)
testword = Worddata(test, getidx = True, rawdata = rawtest)
train_loader = DataLoader(trainword,batch_size=batchsize, shuffle = True)#, num_workers=4
test_loader = DataLoader(testword,batch_size=batchsize,shuffle=True)#, num_workers=4
maxlength =wordlength

# %%
model = WordRNN(bidirection=True)
state = torch.load(modelpath)
model = model.to(device)
try:
    model.load_state_dict(state['state_dict'])
except:
    model = torch.nn.DataParallel(model).to(device)
    model.load_state_dict(state['state_dict'])
    model = model.module

# %%
alltimebest = 0
bestfeature = []
def recoveradv(rawsequence, index2word, inputs, advwords):
    filters='!"#$%&()*+,-./:;<=>?@[\\]^_`{|}~\t\n '
    rear_ct = len(rawsequence)
    advsequence = rawsequence[:]
    try:
        for i in range(inputs.size()[0]-1,-1,-1):
            wordi = index2word[inputs[i].item()]
            rear_ct = rawsequence[:rear_ct].rfind(wordi)
                
            if inputs[i].item()>=3:
                advsequence = advsequence[:rear_ct] + advwords[i] + advsequence[rear_ct + len(wordi):]
    except:
        print('something went wrong')
    return advsequence

# %%
def attackword():
    corrects = .0
    total_loss = 0
    model.eval()
    wordinput = []
    tgt = []
    adv = []
    origsample = []
    origsampleidx = []
    
    for dataid, data in enumerate(test_loader):
        print(dataid)
        inputs,target, idx, raw = data
        inputs, target = inputs.to(device), target.to(device)
        origsample.append(inputs)
        origsampleidx.append(idx)
        tgt.append(target)
        wtmp = []
        output = model(inputs)
        pred = torch.max(output, 1)[1].view(target.size())
        
        losses = scorefunc(scoring)(model, inputs, pred, numclass)
        
        sorted, indices = torch.sort(losses,dim = 1,descending=True)

        advinputs = inputs.clone()
        
        for k in range(inputs.size()[0]):
            wtmp.append([])
            for i in range(inputs.size()[1]):
                if advinputs[k,i].item()>3:
                    wtmp[-1].append(index2word[advinputs[k,i].item()])
                else:
                    wtmp[-1].append('')
        for k in range(inputs.size()[0]):
            j = 0
            t = 0
            while j < power and t<inputs.size()[1]:
                if advinputs[k,indices[k][t]].item()>3:
                    word, advinputs[k,indices[k][t]] = transform(transformer)(advinputs[k,indices[k][t]].item(),word_index,index2word, top_words = dictionarysize)
                    wtmp[k][indices[k][t]] = word
                    #print(word)
                    j+=1
                t+=1
        adv.append(advinputs)
        
        output2 = model(advinputs)
        pred2 = torch.max(output2, 1)[1].view(target.size())
        corrects += (pred2 == target).sum().item()
        
        for i in range(len(wtmp)):
            print(raw[i])
            print(pred[i].item())
            wordinputi = recoveradv(raw[i],index2word,inputs[i], wtmp[i])
            print(wordinputi)
            wordinput.append(wordinputi)
            print(pred2[i].item())

 

    target = torch.cat(tgt)
    advinputs = torch.cat(adv)
    origsamples = torch.cat(origsample)
    origsampleidx = torch.cat(origsampleidx)
    acc = corrects/advinputs.size(0)
    print('Accuracy %.5f' % (acc))

    adv_texts=pd.DataFrame([i for i in zip(target,wordinput)] )
    #print(adv_texts.head())
    adv_texts.to_csv("covid_wordrnn_test_adv_samples_charInsert.csv", sep=',',index=False,header=False)

# %%
index2word = {}
index2word[0] = '[PADDING]'
index2word[1] = '[START]'
index2word[2] = '[UNKNOWN]'
index2word[3] = ''
if dictionarysize==20000:
    for i in word_index:
        if word_index[i]+3 < dictionarysize:
            index2word[word_index[i]+3]=i
else:
    for i in word_index:
        if word_index[i] + 3 < dictionarysize:
            index2word[word_index[i]+3]=i  
attackword()
# Out:
# 0
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:26: UserWarning: Implicit dimension choice for log_softmax has been deprecated. Change the call to include dim=X as an argument.
# /usr/local/lib/python3.6/dist-packages/torch/nn/_reduction.py:43: UserWarning: size_average and reduce args will be deprecated, please use reduction='none' instead.
#   warnings.warn(warning.format(ret))
# Streaming output truncated to the last 5000 lines.
# 0
# probably one of my favorite things in all these pressers is that pence keeps saying  as the president always says were all in this together yet trump never says that legit never says that from what ive heard covid19
# 0
# probably one of my favorite things in all these pressers is that pence keeps saying  as the president always ssays were all in this together yet trump nehver sfays that legite lnever sasys mthat fromz wahat ive heard coovid19
# 0
# the trump administration is trying to turn coronavirus into the reichstag fire covid19
# 0
# thte trumpm advministration is trying ton lturn coronxavirus ainto thfe reichstag gfire covid19n
# 0
# we stand by italy during these trying times share your support for our italian friends they are our colleagues friends and family cari amici siamo con voi covid19 westandwithitaly
# 0
# we stand by italy during these trying times share your support for our italian friends theyj are ouhr colleagues fjriends and family cgari admici siasmo cone nvoi cobvid19 westandwtithitaly
# 0
# what a start of janatacurfew
# stayhome stayhomeindia coronaviruspandemic
# 0
# whato ua stiart qof kjanatacurfew
# stayhome stamyhomeindia coronavirudspandemic
# 0
#  6197987 2     also it cant actually be used for people infected with covid19 but rather only for people with other ailments at least until the first coronavirususa patient unknowingly makes it on board and then the whole ship becomes a petri dish for breeding even more new cases
# 0
# the  administration runs to the rescue of what the  sezes as most impietant hint it’s nfot the american peopcle butt igt uis fthat cnasty socialisfm thhey rally against coronavirus banks
# 1
# this coronavirus is azab frm allah swt we shd blv in allah nd hv patience
# 1
# thhis coronavirus igs azab frm allah sywt uwe shdz blv inb uallah nde hfv patientce
# 0
# stay healthy people and dont live in fear
#
#
#
# covid19 nofear designkingson coronaviruspandemic
# 1
# srtay hejalthy zpeople anpd idont liive ind feaqr
#
#
#
# covimd19 nofeaor designkingson coronaviruspandemic
# 0
#  nomi  businesses amp their assets must be preserved and protected though the covid19 crisis heres how gtgt   businesshibernation
# 0
#  nomi  businebsses ampt theiwr assetsc must be preserved cand protected though dthe covid19i craisis heres how gtgto   businbqeshibernation
# 0
# happening now ca gov  provides covid19 update
# major props to the incredible asl interpreter
#
#
# 1
# happending now can wgov  praovides czovid19 updante
# majior props gto the inqcredible masl interpreter
#
#
# 0
# tweet 2 making a coronaviruspandemic playlistcd featuring such gems as this    i would admire your input and others if they want to help please retweet people
# 0
# tweet 2 making a coronaviruspandemic playlistjcd featuring such gaems as this    i would admire youru ninput and others if theya wavnt to uhelp plefase retwefet peoplge
# 0
#  myths about coronavirus myths and facts about covid19
#
#
#
# jantacurfew  coronavirusoutbreakindia covid2019india coronavirusindia covid19 coronaviruspandemic coronaoutbreak
#  coronacrisis
# 0
#  myths about coronavirus mythsa agnd facxts akbout covid19
#
#
#
# jantacurfew  corqonavirusoutbreakindia covid20s19india coronavirusindia covid19o coronaviruscpandemic coronapoutbreak
#  coronacrisois
# 0
# you  can take your profits from your covid19 insidertrading and give it to helping respond to this pandemic otherwise take your i’llgotten gains and resign slimeofhumanity
# 1
# you  can take your profits from your covid19 insidertrading and givpe it to haelping responjd txo thois pandemmic ogtherwise tnake your i’llgotten gaqins andy resign slimeofhumanity
# 0
# when your landlord tells you rent payments are their entire income tell them to go out and get a job and im a landlord covid19
# 1
# when yourg landlvord tellls byou renbt payments are their entire isncome teltl theom tvo dgo out and get a job and im a landlord covid19
# 0
# lockdownpakistan
# finally notification aagya k lockdown hone k chances hen
# stayhomestaysafe
# coronaviruspandemic
# covidiot
# quarantineactivities
# lockdown
# coronafreepakistan
# 0
# lockdownpakistan
# finally noxtification aagya k lwockdown rhone gk chandces hen
# stayhomesbtaysafe
# coronaviruspanademic
# covidiot
# quarantinezactivities
# lockdownk
# coronafreewpakistan
# 0
# what coronaviruspandemic covid19
# 0
# uwhat coronaviruspyandemic covgid19
# 0
# anyone else randomly checking their temperature four times a day for no apparent reason coronaviruspandemic covidiot sendhelp
# 1
# anyonke else rfandomly checkingo their tempverature fotur timres am day bfor no apparent reason coronatviruspandemic cbovidiot sendhelp
# 0
# apparently michigan governor  has exempted churches from the ban on 50 gatherings 🤷‍  why stayhome coronaviruspandemic bettersafethansorry
# 0
# apparently michigan governor  has exempted churches cfrom rthe banj one o50 gaytherings 🤷‍n  dwhy stayhoume coronavireuspandemic bettersafethansorry
# 0
# cash give always
#
# cash cashappfriday coronaviruspandemic money italy savetheday kanyewestisoverparty covid19 giveaway iphonex staysafestayhome staysafestayhome savetheday sales
# 0
# cash givee falways
#
# cash cashjappfriday coronaviruspanndemic money ittaly savetheday kanyewenstisoverparty ycovid19 givueaway iphonex staysafestayhomeg staysafestayhomwe savetheday sales
# 0
# we stand by italy during these trying times share your support for our italian friends they are our colleagues friends and family cari amici siamo con voi covid19 westandwithitaly
# 0
# we stand by italy during these trying times share your support for our italian friends tphey are ourx colleagues friendsz and family carit ampici siramo ucon vooi covitd19 westandwithitahly
# 0
# coronavirus italy escalates lockdown as death toll rises coronavirus
# 0
# coronavilrus itcaly escalatesg lockdowyn aps dedath toull risesy cgoronavirus
# 0
# when you and your brother have to work from home at same time
#
# side effects of covid19
# 0
# whena yonu anqd your brother have to worki frokm hoome uat same time
#
# side effecsts olf covuid19
# 0
# so the lockdowns working  coronavirus
# 0
# syo thoe lockdowbns wnorking  cdoronavirus
# 0
#  16604 yeah covid19 is eventually killing more people than mountain lions
# 1
#  16604 yeaho covied19 isf evenrtually ykilling muore qpeople thtan mountaizn lxions
# 0
# all this rona talk got me feeling like we in a movie where the good guys legit lose and the bad guys plan really comes to life coronaviruspandemic
# 1
# all this rona talk got me feeling like we in a miovie where the pgood gucys lelgit loose and the bad gkuys plan reyally comets mto lifze coronaviruspandemic
# 0
# well just caught my kid acting out someone running on subway platform and missing f train so that’s the beginning of a whole new coronavirus nyc isolation universe of whathappenedtotheworldiknew play
# 1
# well just caught my kid actking out someone running zon subway pliatform and missing f train so that’s thle bseginning of a dwhole gnew coronavirus nyc isolatieon univyerse ofb whathappenedtotheworldiknew play
# 0
# sbi announces emergency credit line in light of covid19  the economic times  covid19 coronavirus economy credit loans
# 1
# sbi announces ecmergency ciredit line iyn lidght oqf covid19  thef economhic timmes  coovid19 coronavirus economy crqedit loans
# 0
# it’s amazing how many new faces i’m seeing suddenly in my apartment building  lots of ‘canadians’ who don’t seem to speak any english  weird  coronaviruscanada  covid19
# 1
# it’s amatzing how manyw nesw jfaces i’m seeing suddenly iqn rmy capartment building  lots omf ‘canadians’ who don’t seem to speak anyv engblish  weird  coronaviruscanada  covid19
# 0
# based on social media sciencethat video of the pepper and soapthose kids doing the tide pod challenge were really onto smothering coronaviruspandemic
# 1
# based on socieal megdia sciencethat vyideo oof thel pepzper and soapthose kids doing nthe tide pod challenge xwere jreally ontob smothering coronaviandpandemic
# 0
# this pandemic is far more significant than the crashing of the aca website on initial launch by magnitudes but yall keep telling yourselves ol donnie is doing a good job
# coronaviruspandemic covid19
# 1
# this pandeomic is falr morge signifiucant than the crashing ofo the aca website on initial launch tby bmagnitudes but yall keep telling yourselves ovl donnie is doing a goodw job
# csoronaviruspandemic covid19
# 0
#  resign
#
#   covidiot trumpmeltdown trumprecession trumpliespeopledie coronaviruspandemic
# 0
#  resixgn
#
#   covidiiot trudmpmeltdown trumprsecession otrumpliespeopledie coronavirushpandemic
# 0
# lets all pray
#
# coronaviruspandemic
# philippines
# 0
# ulets zall prnay
#
# coronavicruspandemic
# philippibnes
# 0
# lockdown indiafightcorona
#
# 0
# dear people please dont trust any rumours amp forwarded messages like audio clkip  vpideos ambout corona
#
# sjtay hompe
# we will comply with egovernment orduers janotacurfew
# isupptortjantacurfew
#
# coronaupdatesinindia
# coronaviruspandemich
# lockdown indiafightcorona
#
# 0
# only we as a responsible individual can stop the catastrophic rush of coronaviruspandemic great move by   which is highly supported by india in an attempt to indiafightscorona
# 1
# only we as a respponsible indnividual can stop the catastrophic rush xof coronaviruspandemic greazt movex by   which is highlyk supported by inxdia in awn attempwt to indiafightoscorona
# 0
# a canadian hard at work sowing distrust in the coronaviruspandemic it wants us taking the same precautions as the flu so we can get back to our jobs spending money at big box stores and risking our lives the survival of society for short term profits aka just another day
# 0
# a canadian hardl fat work sowing distrust in the coronaviruspandemic it wants us taking the same precautions as the flu so we can get back to our vjobs spcending money jat big box fstores aand risking our lives the survival of somciety foyr short term profits akja just another day
# 0
#  sir   why dont v leave it 2 d people of our country 2 gv honour n respect 2 d frontline army of personnel who r helping us fight coronavirus  in whatever manner they want
#  but most importantly lets support them with more kit testing kit ventilators etc
# 1
#  sir   why dont v leave it 2 d people of our country 2 gv honourj nr respec2 2 d frontline army of personnel who r helping us fixght coronavirus  in whatever matnner they want
#  but modst importanztly lets suppornt ithem with morer kkit testing kit ventilators etc
# 0
# we hope all of you are indoors lets together fight covid19
# 0
# woe hopme allh oyf jyou dare indoors lgets itogether fihght covimd19
# 0
# another great indepth coronavirus article from  like socialdistancing it is very much worth persevering with
# 1
# anaother grezat indepth coronavirus artitcle fromx  like socialdisthancing tit is overy mbuch aworth persevering wivth
# 0
#  why so hard to use the name everyone else is using
#
# stop trying to create yet another name
#
# this virus i like to call the china virus no one was saying that now everyones saying it
#
# no theyre not coronavirus covid19
# 0
#  why so hard to use the name everyone else is using
#
# stop trying to create yet another name
#
# this virus i like to call thee chinka virus no one was sayigng athat noww everyonels saying it
#
# lno htheyre not coronmavirus cohvid19
# 0
# soaking in some sun during californialockdown mercifully i just have to step out without leaving the house for some fresh air stayathome quaratinelife coronaviruspandemic coroanvirus quarantineactivities covid19 sanfrancisco oakland california usa socialdistancing
# 0
# soaking nin some sun during califocrnialockdown mercifully i just have to step out without leaving tthe house for some fresh aiur stayathome quaratinelixfe coronaviruspandermic corojanvirus quarantineactivities covid19 saunfrancisco oakland california susa socialdistancikng
# 1
# shout out to all internists out there who work their asses off during this period aside from taking care of their patients they also have to do a lot of researches readamplearn hundreds of recent medical literatures revise and update the covid19 guidelines as soon as possible
# 0
# shout out to all internists out there who work ttheir assaes off during this period asidie friom takingw care of thevir patienxts they also have to do a lot of researches readamplearn hundreds off recent medical literatures revise and update the covid19 guidelines as soon ags possnible
# 1
#  if trump was intelligent hadn’t ignored intelligence demolished cdc amp taking coronavirus serious early january there’d be less dead less job loss and everything else that just toppled down due to hearing the dummy amp  spreading the childish hoax bull
# 1
#  if trump waus intehlligent hadn’t ignokred intelligence demolished cdc amp taking coronavirus serious earlvy january there’d be less dead less job lolss andv everything else that just toppled down due to hcearing the duwmmy amp  spreading the jchildish hoax bpull
# 0
# ...
# 0
# dont look at the absolute numbers pay attention to the slope angle the tendency us we need to slow it jdown please do socialdistancing amp dont downt play tnhe disease severity it jwill touch youz one waly or anonther covpid19 coqvid19 coronaviaruspandemic sarscov2
# 0
# boost your immune system with natural herbs and spices
#
# if you are based in india and want the following to be delivered to u pl ping us
#
# covid19 corona immunesystem immunityboost
# 1
# boohst yourd imwmune system with ngatural herabs and spices
#
# ixf you are based in india and want the following to be rdelivered to u pl pingo us
#
# covid19 corolna immunensystem immunityboost
# 0
# fox news is a hotspot for covid19 infection sad
#
#
# 0
# afox newls isd ka hotspgot foqr covid1o9 infecttion sadl
#
#
# 0
# coronavirus italy escalates lockdown as death toll rises coronavirus
# 0
# cyoronavirus italyt escalastes lockdowyn als deyath tolql risses cporonavirus
# 0
# me and bro tryna sneak to the gas station during lockdown
#
# coronavirus quarantine
# 0
# eme agnd bro tryna sneak toa thve gras statieon duwring lmockdown
#
# coronaviruus squarantine
# 0
# meanwhile i think a lot of the workforce in the bay area will realize and will have an irrefutable proof they are just fine working from home and will move out to more affordable places covid19
# 1
# meanwhile i think a lot of the workforce in the bay area will realize and will have an irrefutable proof they alre jfust hfine working from hoane aqnd will myove omut uto moreg haffordable places covid19
# 0
# on the cleveland scanner the police got a call 100 people jumping on vehicles
# riot looting coronaviruspandemic covid19 socialdistancing coronavirusoutbreak costco coronavirusupdate
# 0
# on the cleveland scanner the polvice got a call 10i0 peaople jumpintg on voehicles
# rpiot looting coronvaviruspandemic cohvid19 socialddistancing coronavirusoutbreaki costco coronavirusupdate
# 1
# missing baseball has be dusting off the old classics watching nolan ryan’s last no hitter covid19
# 0
# mipssing basebalrl hasr lbe dusting off thee old classics watmching nfolan ryan’s lhast nbo hitter coivid19
# 1
# now showing a certain baba explaining how to build immunity and test for covid19 at home
# is this a fever dream
#
# india
#
# janatacurfew merabharatmahaan covid19india
# 1
# now showing a cnertain babea exeplaining hown vto buizld immunity and test for covidh19 at home
# is this a fevejr dream
#
# india
#
# janatacurfewu merabharatmahaan xcovid19india
# 0
# there was huge rush in front of liqueur shop yesterday but no one came to join as corona warriors with health department
#
# coronaviruspandemic
# dipr
#  sudhakar
# 1
# thewre wasz phuge drush in front ofn liqueur shopn yesterdday but no onej came to join as corona warriors with health department
#
# coronaviruspkandemic
# dgipr
#  sudhakar
# 0
# g it’s here in the community amp it’s real 3 cheers for ardern  will she declare level 4 now or will  she hold another electioneering breaking news moment and talk to us like  we’re  little kids amp deny it  too little too late nzpol  covid19
# 0
# g it’s here in the community amp it’s real 3 cheers for ardern  will she declare level 4 nowv or will  she hold another electioneering breaking news momment and taldk to us like  we’re  little kidrs ampl deny lit  too slittle tozo leate nzpol  covoid19
# 0
# this is just an epic comeback
# covidiot coronavirus covid19
# 0
# xthis isn jtust aqn ezpic commeback
# covidiodt coronadvirus covidy19
# 0
#  lysssss hey man check out  new test out of colorado spread the word so we can save some lives by getting tests out there aytu coronaviruspandemic tests
# 0
#  lysssss hey man check outt  new test ojut osf colorahdo spread the wordo sou bwe can savle some lives by getuting tests out there aytu coronaviruspandemic testsw
# 1
